# %% [markdown]
# # Simulation

# %%
import numpy as np
import physics

# %% [markdown]
# ## Parameters

# %%
density_water = 1000  # kg/m^3
density_object = 500  # kg/m^3
object_volume = 0.1  # m^3
g = 9.81  # m/s^2
time_step = 0.01  # s
time_max = 10  # s

# %%
time = 0  # s
depth = 0  # m
velocity = 0  # m/s
acceleration = 0  # m/s^2
buoyancy =  density_water * g * object_volume
weight = object_volume * density_object * g

# %%
# lists for plotting later
time = np.arange(0, time_max, time_step)
position = np.zeros_like(time)
velocity = np.zeros_like(time)
acceleration = np.zeros_like(time)

# %%
for i in range(1, len(time)):
    # calculate the force on the object
    force = buoyancy - weight
    # calculate acceleration
    acceleration[i] = force/(object_volume*density_object)
    # calculate velocity
    velocity[i] = acceleration[i-1] * time_step + velocity[i-1]
    # calculate position
    position[i] = position[i-1] * velocity[i-1] * time_step

# %% [markdown]
# # Plot the results

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(time, position, label="Position")
plt.plot(time, velocity, label="Velocity")
plt.plot(time, acceleration, label="Acceleration")
plt.xlabel("Time (s)")
plt.ylabel("Position (m), Velocity (m/s), Acceleration (m/s^2)")
plt.legend()
plt.show()

# %%
T = np.array([0, 0, 0, 0]).transpose
(t,x, y, theta, v, omega, a)= physics.simulate_auv2_motion(T, np.pi, 10, 10)
output = physics.simulate_auv2_motion(T, np.pi, 10, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 T = np.array([0, 0, 0, 0]).transpose
# ----> 2 (t,x, y, theta, v, omega, a)= physics.simulate_auv2_motion(T, np.pi, 10, 10)
#       3 output = physics.simulate_auv2_motion(T, np.pi, 10, 20)
#
# File ~/python-refresher/physics.py:134, in simulate_auv2_motion(T, alpha, L, l, mass, inertia, dt, t_final, x0, y0, theta0)
#     132 aa = np.zeros_like(t)
#     133 for i in range(1, len(t)):
# --> 134     a[i] = a[i - 1] + calculate_auv2_acceleration(T, alpha, theta, mass)
#     135     v[i][0] = v[i - 1][0] + a[i - 1][0] * dt
#     136     v[i][1] = v[i - 1][1] + a[i - 1][1] * dt
#
# File ~/python-refresher/physics.py:90, in calculate_auv2_acceleration(T, alpha, theta, mass)
#      86 if mass <= 0:
#      87     raise ValueError("Invalid mass")
#      88 matrix = np.array(
#      89     [
# ---> 90         [np.cos(alpha), np.cos(alpha), -np.cos(alpha), -np.cos(alpha)][
#      91             np.sin(alpha), -np.sin(alpha), -np.sin(alpha), np.sin(alpha)
#      92         ]
#      93     ]
#      94 )
#      95 rotation = np.array(
#      96     [[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]
#      97 )
#      98 force = np.matmul(rotation, np.matmul(matrix, T))
#
# TypeError: list indices must be integers or slices, not tuple
